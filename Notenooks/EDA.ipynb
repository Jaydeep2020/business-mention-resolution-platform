# %%
import pandas as pd

# %%
data_path = "D:/Sculptsoft/business-mention-resolution-platform/data/raw_data/yelp_academic_dataset_review.json"


chunks = pd.read_json(data_path, lines=True, chunksize=100000)

# %%
df = next(chunks)

# %%
print(df.sample(1))
# Out:
#                     review_id                 user_id             business_id  \
# 20900  Ycu0se8S0jsHVF9p4Nl_ww  IsfqByg7NeyJKFCSudsmfg  TCHh4RIrvp7h2BucXt1kvA
#
#        stars  useful  funny  cool  \
# 20900      1       0      0     0
#
#                                                     text                date
# 20900  Just went here in October and there was no air... 2017-10-12 02:31:19

# %%
df.sample(2)
# Out:
#                     review_id                 user_id             business_id  \
# 32714  11hLZSrWtG7yf1uupprQmw  Q9RltWJdfayzRArINKlE1w  X2D42cGnqxadT_jbNJxHsg
# 48693  z96b9f1cSsFNYOcoRmDFoQ  k5HKFBJr7nsRox9p2ZIF8g  3uYVhF4XqaZfKZg1pnLA2w
#
#        stars  useful  funny  cool  \
# 32714      5       0      0     0
# 48693      4       0      0     0
#
#                                                     text                date
# 32714  As others have said, these guys are great!  We... 2014-12-03 03:19:39
# 48693  Home away from home...I seem to be here all th... 2018-07-20 12:30:38

# %%
for i in df.iloc[40000:40009, 7]:
    print(i)
    print()
# Out:
# I was unexpectedly surprised with how much I liked this place. I came here for a late dinner, just wanting something small and light since I've been eating all day. It's a pretty small and cozy place, with a few tables outside. All the tables were taken, but we were able to sit at the high tops where they made the pizzas. Best seats in the house!
#
# They were super efficient in making the pizzas. All the ingredients looked fresh and plentiful on the pizzas themselves. The pies coming out of their wood burning oven looked amazing. I enjoyed watching them make them through the night. Looking at that, as well as the menu, I didn't want anything small anymore but wanted to try a little bit of everything.
#
# Got the Italian Cesar salad- anchovies topped the salad so it had that saltiness in each and every bite. The pizza dough as the croutons were warm and doughy.
#
# While waiting for our pizza, they had an extra calzone and hooked it up for free. Thanks!
#
# ...

# %%
df.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars', 'useful', 'funny',
#        'cool', 'text', 'date'],
#       dtype='str')

# %%
data_path = "D:/Sculptsoft/business-mention-resolution-platform/data/raw_data/yelp_academic_dataset_business.json"


chunks2 = pd.read_json(data_path, lines=True, chunksize=100000)

# %%
df2 = next(chunks2)

# %%
print(df2.sample(1))
# Out:
#                   business_id                 name          address   city  \
# 62288  PB8LPiw46BXq40AFLZqxkQ  Wolff's Apple House  81 S Pennell Rd  Media
#
#       state postal_code   latitude  longitude  stars  review_count  is_open  \
# 62288    PA       19063  39.906734 -75.439729    4.5            38        1
#
#                                               attributes  \
# 62288  {'BusinessParking': '{'garage': False, 'street...
#
#                                               categories  \
# 62288  Food, Fruits & Veggies, Farmers Market, Grocer...
#
#                                                    hours
# 62288  {'Monday': '8:0-18:0', 'Tuesday': '8:0-18:0', ...

# %%
df2.columns
# Out:
# Index(['business_id', 'name', 'address', 'city', 'state', 'postal_code',
#        'latitude', 'longitude', 'stars', 'review_count', 'is_open',
#        'attributes', 'categories', 'hours'],
#       dtype='str')

# %%
df2.sample(2)
# Out:
#                   business_id                  name              address  \
# 83245  7V7cxGLM-xZ7C44-1DfvSw           Chubby crab  5717 Rising Sun Ave
# 76248  UPzloPwTmQymKLht9epxbA  The Tavern at Cheval     4312 Cheval Blvd
#
#                city state postal_code   latitude  longitude  stars  \
# 83245  Philadelphia    PA       19120  40.041642 -75.105872    2.5
# 76248          Lutz    FL       33558  28.152595 -82.510104    4.0
#
#        review_count  is_open  \
# 83245             9        0
# 76248             9        1
#
#                                               attributes  \
# 83245  {'Ambience': '{'touristy': False, 'hipster': F...
# 76248  {'BusinessAcceptsCreditCards': 'True', 'BYOB':...
#
#                                               categories  \
# 83245        Fish & Chips, Burgers, Restaurants, Seafood
# 76248  American (Traditional), Restaurants, Nightlife...
#
#                                                    hours
# ...

# %%
len(df2.columns)
# Out:
# 14

# %%
df2.shape
# Out:
# (100000, 14)
